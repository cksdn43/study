# %%
# 1
import pandas as pd

df = pd.read_csv('archive\iris.data.csv', header=None)
df.loc[0]
# Out:
# 0            5.1
# 1            3.5
# 2            1.4
# 3            0.2
# 4    Iris-setosa
# Name: 0, dtype: object

# %%
df.columns  = ['Sepal_length','Sepal_width','Petal_length','Petal_width','Species']
df.loc[0]
# Out:
# Sepal_length            5.1
# Sepal_width             3.5
# Petal_length            1.4
# Petal_width             0.2
# Species         Iris-setosa
# Name: 0, dtype: object

# %%
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# 2-1
df['Species'][0]
# Out:
# 'Iris-setosa'

# %%
# 2-2
df[['Sepal_length', 'Sepal_width', 'Petal_length','Petal_width']]
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# 2-3
df.loc[:,'Sepal_length':'Petal_width']
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
# 2-4
df[['Petal_length','Species']]
# Out:
#      Petal_length         Species
# 0             1.4     Iris-setosa
# 1             1.4     Iris-setosa
# 2             1.3     Iris-setosa
# 3             1.5     Iris-setosa
# 4             1.4     Iris-setosa
# ..            ...             ...
# 145           5.2  Iris-virginica
# 146           5.0  Iris-virginica
# 147           5.2  Iris-virginica
# 148           5.4  Iris-virginica
# 149           5.1  Iris-virginica
#
# [150 rows x 2 columns]

# %%
# 2-5
df.iloc[10:14]
# Out:
#     Sepal_length  Sepal_width  Petal_length  Petal_width      Species
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa

# %%
#3-1
a = df['Species'][0]
a.split('-')[1]
# Out:
# 'setosa'

# %%
#3-2
a = df['Species'][0]
a.replace('Iris-','')
# Out:
# 'setosa'

# %%
#3-3
c = df['Species'].str.replace('Iris-','')
df['Species_1'] = c
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      Species_1
# 0       setosa
# 1       setosa
# 2       setosa
# ...

# %%
#3-4
d = df['Species'].str.split('-', n=1, expand=True)
df['Species_2'] = d.drop(0, axis=1)
df
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width         Species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      Species_1  Species_2
# 0       setosa     setosa
# ...

# %%
# 4-1
S = {}

for i in df['Species_2']:
    if i not in S:
        S[i] = 1
    else:
        S[i] +=1
print(S)
# Out:
# {'setosa': 50, 'versicolor': 50, 'virginica': 50}

# %%
# 4-2
from collections import Counter
Counter(df['Species_2'])
# Out:
# Counter({'setosa': 50, 'versicolor': 50, 'virginica': 50})

# %%
# 4-3
f = df['Species_2'].value_counts()
f
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: Species_2, dtype: int64

# %%
# 4-4
f.plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
# 4-5
words = Counter(df['Species_2'])
string_data = ''
for word in words:
	string_data = string_data+' '+word
wordcloud = WordCloud(width = 400, height = 400, ).generate(string_data) 
  
# WordCloud 출력                    
plt.figure(figsize = (4, 4), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout() 
plt.show()

# %%
# 4-6
dict_data = S
wordcloud = WordCloud(width = 400, height = 400, 
                      background_color ='black', 
                      stopwords = set(STOPWORDS), 
                      max_words=3,
                      max_font_size = 100,
                     ).generate_from_frequencies(dict_data) 
  
# WordCloud 출력                    
plt.figure(figsize = (4, 4), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout() 
plt.show()
