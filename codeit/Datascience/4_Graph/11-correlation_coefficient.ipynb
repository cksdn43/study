# %%
# %matplotlib inline
import pandas as pd

df = pd.read_csv('exam.csv')

df.corr()
# Out:
# C:\Users\이찬우\AppData\Local\Temp\ipykernel_27684\3984616647.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('exam.csv')

sns.heatmap(df.corr())
# Out:
# C:\Users\이찬우\AppData\Local\Temp\ipykernel_27684\2711651352.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('exam.csv')

sns.heatmap(df.corr(), annot=True)
# Out:
# C:\Users\이찬우\AppData\Local\Temp\ipykernel_27684\476266007.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <AxesSubplot: >
