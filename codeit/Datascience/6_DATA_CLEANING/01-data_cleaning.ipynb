# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('data/attendance.csv', index_col=0)
df
# Out:
#          야구     축구      배구  남자농구  여자농구
# 연도
# 2008  10881  11642  1253.0  4208  1329
# 2009  11562  10983  1471.0  4152  1206
# 2010  11402  12873     NaN  3870   705
# 2011  13055  10709  1774.0  3955  1445
# 2012  13747   7157     NaN  4537  1150
# 2013  11373   7656     NaN  4092  1237
# 2014  11429   8115  1967.0  4458  1417
# 2015  10357   7720  2311.0  3953  1480
# 2016  11583   7854  2336.0  3543  1425
# 2017  11668   6502  2425.0  3188  1097

# %%
df.isnull()
# Out:
#          야구     축구     배구   남자농구   여자농구
# 연도
# 2008  False  False  False  False  False
# 2009  False  False  False  False  False
# 2010  False  False   True  False  False
# 2011  False  False  False  False  False
# 2012  False  False   True  False  False
# 2013  False  False   True  False  False
# 2014  False  False  False  False  False
# 2015  False  False  False  False  False
# 2016  False  False  False  False  False
# 2017  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# 야구      0
# 축구      0
# 배구      3
# 남자농구    0
# 여자농구    0
# dtype: int64

# %%
df.dropna()
# Out:
#          야구     축구      배구  남자농구  여자농구
# 연도
# 2008  10881  11642  1253.0  4208  1329
# 2009  11562  10983  1471.0  4152  1206
# 2011  13055  10709  1774.0  3955  1445
# 2014  11429   8115  1967.0  4458  1417
# 2015  10357   7720  2311.0  3953  1480
# 2016  11583   7854  2336.0  3543  1425
# 2017  11668   6502  2425.0  3188  1097

# %%
df['야구':'배구']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df['야구':'배구']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:3777, in DataFrame.__getitem__(self, key)
#    3775         return self._getitem_multilevel(key)
#    3776 # Do we have a slicer (on rows)?
# -> 3777 indexer = convert_to_index_sliceable(self, key)
#    3778 if indexer is not None:
#    3779     if isinstance(indexer, np.ndarray):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:2494, in convert_to_index_sliceable(obj, key)
#    2492 idx = obj.index
#    2493 if isinstance(key, slice):
# -> 2494     return idx._convert_slice_indexer(key, kind="getitem", is_frame=True)
#    2496 elif isinstance(key, str):
#    2497
#    2498     # we are an actual column
#    2499     if key in obj.columns:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\numeric.py:234, in NumericIndex._convert_slice_indexer(self, key, kind, is_frame)
#     228     # TODO: can we write this as a condition based on
#     229     #  e.g. _should_fallback_to_positional?
#     230     # We always treat __getitem__ slicing as label-based
#     231     # translate to locations
#     232     return self.slice_indexer(key.start, key.stop, key.step)
# --> 234 return super()._convert_slice_indexer(key, kind=kind, is_frame=is_frame)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:4293, in Index._convert_slice_indexer(self, key, kind, is_frame)
#    4282         warnings.warn(
#    4283             "The behavior of `series[i:j]` with an integer-dtype index "
#    4284             "is deprecated. In a future version, this will be treated "
#    (...)
#    4289             stacklevel=find_stack_level(),
#    4290         )
#    4291 if self.is_integer() or is_index_slice:
#    4292     # Note: these checks are redundant if we know is_index_slice
# -> 4293     self._validate_indexer("slice", key.start, "getitem")
#    4294     self._validate_indexer("slice", key.stop, "getitem")
#    4295     self._validate_indexer("slice", key.step, "getitem")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6634, in Index._validate_indexer(self, form, key, kind)
#    6631 assert kind in ["getitem", "iloc"]
#    6633 if key is not None and not is_integer(key):
# -> 6634     raise self._invalid_indexer(form, key)
#
# TypeError: cannot do slice indexing on Int64Index with these indexers [야구] of type str

# %%
df.dropna(inplace=True)
df
# Out:
#          야구     축구      배구  남자농구  여자농구
# 연도
# 2008  10881  11642  1253.0  4208  1329
# 2009  11562  10983  1471.0  4152  1206
# 2011  13055  10709  1774.0  3955  1445
# 2014  11429   8115  1967.0  4458  1417
# 2015  10357   7720  2311.0  3953  1480
